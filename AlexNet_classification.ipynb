# %% [markdown]
# <a href="https://colab.research.google.com/github/hussainturii/Advanced-Computer-Vision---Deep-Learning/blob/main/AlexNet_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import wandb
import os

# %%
# STEP 0: Initialize wandb
wandb.init(project="alexnet-5flowers", config={
    "epochs": 10,
    "batch_size": 16,
    "learning_rate": 0.001,
    "architecture": "alexnet",
    "pretrained": True,
    "input_size": 128
})

# Shortcut to config values
config = wandb.config
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: hussainturi (hussaintoori) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.4
# Run data is saved locally in <code>/content/wandb/run-20250929_194958-sdecl8tc</code>
# Syncing run <strong><a href='https://wandb.ai/hussaintoori/alexnet-5flowers/runs/sdecl8tc' target="_blank">major-cherry-1</a></strong> to <a href='https://wandb.ai/hussaintoori/alexnet-5flowers' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/hussaintoori/alexnet-5flowers' target="_blank">https://wandb.ai/hussaintoori/alexnet-5flowers</a>
#  View run at <a href='https://wandb.ai/hussaintoori/alexnet-5flowers/runs/sdecl8tc' target="_blank">https://wandb.ai/hussaintoori/alexnet-5flowers/runs/sdecl8tc</a>

# %%
# STEP 1: Data Preparation

transform = transforms.Compose([
    transforms.Resize((config.input_size, config.input_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dir = "/content/drive/MyDrive/flowers/train"
val_dir = "/content/drive/MyDrive/flowers/val"

train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
val_dataset = datasets.ImageFolder(root=val_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config.batch_size)

# %%
# STEP 2: Load Pretrained Model

alexnet = models.alexnet(pretrained=config.pretrained)

# Freeze all layers
for param in alexnet.parameters():
    param.requires_grad = False

# Replace the final classifier layer (trainable)
alexnet.classifier[6] = nn.Linear(4096, 5)

# Only the new final layer should be trainable
for param in alexnet.classifier[6].parameters():
    param.requires_grad = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
alexnet = alexnet.to(device)

# Watch the model's weights and gradients
wandb.watch(alexnet, log="all", log_freq=10)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 196MB/s]

# %%
# STEP 3: Loss & Optimizer

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(alexnet.parameters(), lr=config.learning_rate)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, epochs=10):
    for epoch in range(epochs):
        model.train()
        train_correct = 0
        train_total = 0
        running_loss = 0.0

        print(f"\nEpoch {epoch + 1}/{epochs}")
        print("-" * 30)

        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            batch_correct = (preds == labels).sum().item()
            train_correct += batch_correct
            train_total += labels.size(0)

            # Print every 10 batches
            if (i + 1) % 10 == 0:
                batch_acc = batch_correct / labels.size(0)
                print(f"[Batch {i+1}/{len(train_loader)}] Loss: {loss.item():.4f}, Batch Acc: {batch_acc:.4f}")

        train_acc = train_correct / train_total
        wandb.log({"epoch": epoch + 1, "train_loss": running_loss, "train_accuracy": train_acc})
        print(f"Epoch {epoch+1} Summary - Loss: {running_loss:.4f}, Train Accuracy: {train_acc:.4f}")

        # Validation
        model.eval()
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_acc = val_correct / val_total
        wandb.log({"epoch": epoch + 1, "val_accuracy": val_acc})
        print(f"Validation Accuracy: {val_acc:.4f}")

# %%
# Train the model
train_model(alexnet, criterion, optimizer, train_loader, val_loader, epochs=config.epochs)
# Out:
# Epoch 1/10
# ------------------------------
# [Batch 10/251] Loss: 1.1100, Batch Acc: 0.4375
# [Batch 20/251] Loss: 0.7282, Batch Acc: 0.7500
# [Batch 30/251] Loss: 0.4565, Batch Acc: 0.8750
# [Batch 40/251] Loss: 0.6403, Batch Acc: 0.7500
# [Batch 50/251] Loss: 1.2520, Batch Acc: 0.6875
# [Batch 60/251] Loss: 0.3808, Batch Acc: 0.8750
# [Batch 70/251] Loss: 0.8514, Batch Acc: 0.7500
# [Batch 80/251] Loss: 0.6671, Batch Acc: 0.8125
# [Batch 90/251] Loss: 0.4143, Batch Acc: 0.8125
# [Batch 100/251] Loss: 1.3606, Batch Acc: 0.6250
# [Batch 110/251] Loss: 0.2663, Batch Acc: 0.9375
# [Batch 120/251] Loss: 0.5505, Batch Acc: 0.8125
# [Batch 130/251] Loss: 0.8057, Batch Acc: 0.6875
# [Batch 140/251] Loss: 0.6388, Batch Acc: 0.7500
# [Batch 150/251] Loss: 0.5911, Batch Acc: 0.8750
# [Batch 160/251] Loss: 0.5759, Batch Acc: 0.8125
# [Batch 170/251] Loss: 0.4487, Batch Acc: 0.8125
# [Batch 180/251] Loss: 0.6280, Batch Acc: 0.6875
# [Batch 190/251] Loss: 0.6596, Batch Acc: 0.7500
# [Batch 200/251] Loss: 0.7052, Batch Acc: 0.8125
# [Batch 210/251] Loss: 0.3918, Batch Acc: 0.8750
# [Batch 220/251] Loss: 0.4354, Batch Acc: 0.8750
# [Batch 230/251] Loss: 0.9513, Batch Acc: 0.6250
# [Batch 240/251] Loss: 0.4940, Batch Acc: 0.7500
# [Batch 250/251] Loss: 0.6897, Batch Acc: 0.6875
# Epoch 1 Summary - Loss: 196.0525, Train Accuracy: 0.7325
# Validation Accuracy: 0.7962
#
# Epoch 2/10
# ------------------------------
# [Batch 10/251] Loss: 0.7099, Batch Acc: 0.7500
# [Batch 20/251] Loss: 0.6955, Batch Acc: 0.7500
# [Batch 30/251] Loss: 0.3100, Batch Acc: 0.8750
# [Batch 40/251] Loss: 0.4574, Batch Acc: 0.8750
# [Batch 50/251] Loss: 0.4814, Batch Acc: 0.8750
# [Batch 60/251] Loss: 0.5301, Batch Acc: 0.7500
# [Batch 70/251] Loss: 0.2929, Batch Acc: 0.8750
# [Batch 80/251] Loss: 0.1446, Batch Acc: 0.9375
# [Batch 90/251] Loss: 0.3215, Batch Acc: 0.8750
# [Batch 100/251] Loss: 0.1418, Batch Acc: 0.8750
# [Batch 110/251] Loss: 0.2596, Batch Acc: 0.8750
# [Batch 120/251] Loss: 0.1097, Batch Acc: 1.0000
# [Batch 130/251] Loss: 0.3620, Batch Acc: 0.8125
# [Batch 140/251] Loss: 0.4805, Batch Acc: 0.8750
# [Batch 150/251] Loss: 0.4752, Batch Acc: 0.9375
# [Batch 160/251] Loss: 0.3397, Batch Acc: 0.8125
# [Batch 170/251] Loss: 0.3913, Batch Acc: 0.8750
# [Batch 180/251] Loss: 0.2398, Batch Acc: 0.9375
# [Batch 190/251] Loss: 0.4156, Batch Acc: 0.8125
# [Batch 200/251] Loss: 0.1683, Batch Acc: 0.9375
# [Batch 210/251] Loss: 0.5504, Batch Acc: 0.7500
# [Batch 220/251] Loss: 0.5935, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.3067, Batch Acc: 0.9375
# [Batch 240/251] Loss: 0.0185, Batch Acc: 1.0000
# [Batch 250/251] Loss: 0.4460, Batch Acc: 0.7500
# Epoch 2 Summary - Loss: 115.4267, Train Accuracy: 0.8456
# Validation Accuracy: 0.8437
#
# Epoch 3/10
# ------------------------------
# [Batch 10/251] Loss: 0.3335, Batch Acc: 0.8750
# [Batch 20/251] Loss: 0.2715, Batch Acc: 0.8125
# [Batch 30/251] Loss: 0.1770, Batch Acc: 0.9375
# [Batch 40/251] Loss: 0.7513, Batch Acc: 0.6875
# [Batch 50/251] Loss: 0.1751, Batch Acc: 0.9375
# [Batch 60/251] Loss: 0.6404, Batch Acc: 0.7500
# [Batch 70/251] Loss: 0.4935, Batch Acc: 0.8750
# [Batch 80/251] Loss: 0.4189, Batch Acc: 0.8750
# [Batch 90/251] Loss: 0.3181, Batch Acc: 0.8125
# [Batch 100/251] Loss: 0.1723, Batch Acc: 0.9375
# [Batch 110/251] Loss: 0.3989, Batch Acc: 0.8125
# [Batch 120/251] Loss: 0.4747, Batch Acc: 0.8750
# [Batch 130/251] Loss: 0.2921, Batch Acc: 0.8750
# [Batch 140/251] Loss: 0.4316, Batch Acc: 0.9375
# [Batch 150/251] Loss: 0.6183, Batch Acc: 0.8750
# [Batch 160/251] Loss: 0.4878, Batch Acc: 0.9375
# [Batch 170/251] Loss: 0.3355, Batch Acc: 0.8750
# [Batch 180/251] Loss: 0.5434, Batch Acc: 0.8750
# [Batch 190/251] Loss: 0.6677, Batch Acc: 0.7500
# [Batch 200/251] Loss: 0.4995, Batch Acc: 0.9375
# [Batch 210/251] Loss: 0.4226, Batch Acc: 0.8125
# [Batch 220/251] Loss: 0.2838, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.2783, Batch Acc: 0.8125
# [Batch 240/251] Loss: 0.1075, Batch Acc: 1.0000
# [Batch 250/251] Loss: 0.0704, Batch Acc: 1.0000
# Epoch 3 Summary - Loss: 93.7375, Train Accuracy: 0.8740
# Validation Accuracy: 0.8576
#
# Epoch 4/10
# ------------------------------
# [Batch 10/251] Loss: 0.2342, Batch Acc: 0.8750
# [Batch 20/251] Loss: 0.1840, Batch Acc: 1.0000
# [Batch 30/251] Loss: 0.1469, Batch Acc: 0.9375
# [Batch 40/251] Loss: 0.2943, Batch Acc: 0.8750
# [Batch 50/251] Loss: 0.4096, Batch Acc: 0.9375
# [Batch 60/251] Loss: 0.2820, Batch Acc: 0.8750
# [Batch 70/251] Loss: 0.6611, Batch Acc: 0.8750
# [Batch 80/251] Loss: 0.0214, Batch Acc: 1.0000
# [Batch 90/251] Loss: 0.2975, Batch Acc: 0.8125
# [Batch 100/251] Loss: 0.7323, Batch Acc: 0.8125
# [Batch 110/251] Loss: 0.2466, Batch Acc: 0.8125
# [Batch 120/251] Loss: 0.7324, Batch Acc: 0.8750
# [Batch 130/251] Loss: 0.1227, Batch Acc: 0.9375
# [Batch 140/251] Loss: 0.1281, Batch Acc: 0.9375
# [Batch 150/251] Loss: 0.1612, Batch Acc: 0.9375
# [Batch 160/251] Loss: 1.3823, Batch Acc: 0.7500
# [Batch 170/251] Loss: 0.1995, Batch Acc: 0.8750
# [Batch 180/251] Loss: 0.2376, Batch Acc: 0.8750
# [Batch 190/251] Loss: 0.7532, Batch Acc: 0.8750
# [Batch 200/251] Loss: 0.0940, Batch Acc: 0.9375
# [Batch 210/251] Loss: 0.3781, Batch Acc: 0.8125
# [Batch 220/251] Loss: 0.2340, Batch Acc: 0.8750
# [Batch 230/251] Loss: 0.1218, Batch Acc: 1.0000
# [Batch 240/251] Loss: 0.5263, Batch Acc: 0.8750
# [Batch 250/251] Loss: 0.4459, Batch Acc: 0.7500
# Epoch 4 Summary - Loss: 81.6567, Train Accuracy: 0.8865
# Validation Accuracy: 0.8764
#
# Epoch 5/10
# ------------------------------
# [Batch 10/251] Loss: 0.7044, Batch Acc: 0.8125
# [Batch 20/251] Loss: 0.2383, Batch Acc: 0.9375
# [Batch 30/251] Loss: 0.0216, Batch Acc: 1.0000
# [Batch 40/251] Loss: 0.5989, Batch Acc: 0.8125
# [Batch 50/251] Loss: 0.1333, Batch Acc: 0.9375
# [Batch 60/251] Loss: 0.1127, Batch Acc: 0.9375
# [Batch 70/251] Loss: 0.1312, Batch Acc: 1.0000
# [Batch 80/251] Loss: 0.3391, Batch Acc: 0.9375
# [Batch 90/251] Loss: 0.0948, Batch Acc: 0.9375
# [Batch 100/251] Loss: 0.2001, Batch Acc: 0.9375
# [Batch 110/251] Loss: 0.4799, Batch Acc: 0.8125
# [Batch 120/251] Loss: 0.4947, Batch Acc: 0.8750
# [Batch 130/251] Loss: 0.5351, Batch Acc: 0.8125
# [Batch 140/251] Loss: 0.0530, Batch Acc: 1.0000
# [Batch 150/251] Loss: 0.1416, Batch Acc: 0.9375
# [Batch 160/251] Loss: 0.1179, Batch Acc: 0.9375
# [Batch 170/251] Loss: 0.0819, Batch Acc: 1.0000
# [Batch 180/251] Loss: 0.0357, Batch Acc: 1.0000
# [Batch 190/251] Loss: 0.3086, Batch Acc: 0.8125
# [Batch 200/251] Loss: 0.0851, Batch Acc: 1.0000
# [Batch 210/251] Loss: 0.2470, Batch Acc: 0.8750
# [Batch 220/251] Loss: 0.2860, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.8855, Batch Acc: 0.7500
# [Batch 240/251] Loss: 0.5215, Batch Acc: 0.8750
# [Batch 250/251] Loss: 0.3720, Batch Acc: 0.9375
# Epoch 5 Summary - Loss: 70.1841, Train Accuracy: 0.9014
# Validation Accuracy: 0.8823
#
# Epoch 6/10
# ------------------------------
# [Batch 10/251] Loss: 0.2991, Batch Acc: 0.8750
# [Batch 20/251] Loss: 0.0150, Batch Acc: 1.0000
# [Batch 30/251] Loss: 0.1723, Batch Acc: 0.8750
# [Batch 40/251] Loss: 0.1544, Batch Acc: 1.0000
# [Batch 50/251] Loss: 0.4691, Batch Acc: 0.8750
# [Batch 60/251] Loss: 0.5494, Batch Acc: 0.8750
# [Batch 70/251] Loss: 0.1511, Batch Acc: 0.9375
# [Batch 80/251] Loss: 0.1627, Batch Acc: 0.9375
# [Batch 90/251] Loss: 0.0564, Batch Acc: 1.0000
# [Batch 100/251] Loss: 0.0905, Batch Acc: 1.0000
# [Batch 110/251] Loss: 0.0589, Batch Acc: 1.0000
# [Batch 120/251] Loss: 0.2421, Batch Acc: 0.9375
# [Batch 130/251] Loss: 0.0146, Batch Acc: 1.0000
# [Batch 140/251] Loss: 0.1876, Batch Acc: 0.8750
# [Batch 150/251] Loss: 0.2138, Batch Acc: 0.9375
# [Batch 160/251] Loss: 0.3500, Batch Acc: 0.8750
# [Batch 170/251] Loss: 0.2271, Batch Acc: 0.9375
# [Batch 180/251] Loss: 0.0226, Batch Acc: 1.0000
# [Batch 190/251] Loss: 0.2767, Batch Acc: 0.8750
# [Batch 200/251] Loss: 0.5635, Batch Acc: 0.7500
# [Batch 210/251] Loss: 0.1738, Batch Acc: 0.9375
# [Batch 220/251] Loss: 0.6371, Batch Acc: 0.8125
# [Batch 230/251] Loss: 0.3278, Batch Acc: 0.9375
# [Batch 240/251] Loss: 0.2004, Batch Acc: 0.9375
# [Batch 250/251] Loss: 0.4491, Batch Acc: 0.9375
# Epoch 6 Summary - Loss: 72.7537, Train Accuracy: 0.8990
# Validation Accuracy: 0.8803
#
# Epoch 7/10
# ------------------------------
# [Batch 10/251] Loss: 0.4925, Batch Acc: 0.8125
# [Batch 20/251] Loss: 0.2724, Batch Acc: 0.9375
# [Batch 30/251] Loss: 0.0717, Batch Acc: 1.0000
# [Batch 40/251] Loss: 0.2094, Batch Acc: 0.9375
# [Batch 50/251] Loss: 0.1826, Batch Acc: 0.9375
# [Batch 60/251] Loss: 0.3069, Batch Acc: 0.9375
# [Batch 70/251] Loss: 0.4936, Batch Acc: 0.8750
# [Batch 80/251] Loss: 0.0217, Batch Acc: 1.0000
# [Batch 90/251] Loss: 0.0335, Batch Acc: 1.0000
# [Batch 100/251] Loss: 0.2644, Batch Acc: 0.8750
# [Batch 110/251] Loss: 0.4337, Batch Acc: 0.8750
# [Batch 120/251] Loss: 0.4278, Batch Acc: 0.8750
# [Batch 130/251] Loss: 0.3576, Batch Acc: 0.8125
# [Batch 140/251] Loss: 0.2667, Batch Acc: 0.8750
# [Batch 150/251] Loss: 0.1527, Batch Acc: 0.8750
# [Batch 160/251] Loss: 0.0707, Batch Acc: 0.9375
# [Batch 170/251] Loss: 0.1245, Batch Acc: 0.9375
# [Batch 180/251] Loss: 0.0815, Batch Acc: 1.0000
# [Batch 190/251] Loss: 0.4650, Batch Acc: 0.8125
# [Batch 200/251] Loss: 0.1625, Batch Acc: 0.8750
# [Batch 210/251] Loss: 0.2160, Batch Acc: 0.9375
# [Batch 220/251] Loss: 0.1376, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.4124, Batch Acc: 0.8750
# [Batch 240/251] Loss: 0.3481, Batch Acc: 0.8750
# [Batch 250/251] Loss: 0.0446, Batch Acc: 1.0000
# Epoch 7 Summary - Loss: 66.8151, Train Accuracy: 0.9082
# Validation Accuracy: 0.8912
#
# Epoch 8/10
# ------------------------------
# [Batch 10/251] Loss: 0.1499, Batch Acc: 0.9375
# [Batch 20/251] Loss: 0.0788, Batch Acc: 1.0000
# [Batch 30/251] Loss: 0.5509, Batch Acc: 0.8125
# [Batch 40/251] Loss: 0.0615, Batch Acc: 1.0000
# [Batch 50/251] Loss: 0.1823, Batch Acc: 0.9375
# [Batch 60/251] Loss: 0.1197, Batch Acc: 0.9375
# [Batch 70/251] Loss: 0.1030, Batch Acc: 0.9375
# [Batch 80/251] Loss: 0.1197, Batch Acc: 0.9375
# [Batch 90/251] Loss: 0.0715, Batch Acc: 1.0000
# [Batch 100/251] Loss: 0.0960, Batch Acc: 1.0000
# [Batch 110/251] Loss: 0.1804, Batch Acc: 0.9375
# [Batch 120/251] Loss: 0.3252, Batch Acc: 0.8125
# [Batch 130/251] Loss: 0.6274, Batch Acc: 0.8750
# [Batch 140/251] Loss: 0.3564, Batch Acc: 0.9375
# [Batch 150/251] Loss: 0.3998, Batch Acc: 0.8750
# [Batch 160/251] Loss: 0.2459, Batch Acc: 0.8750
# [Batch 170/251] Loss: 0.0772, Batch Acc: 1.0000
# [Batch 180/251] Loss: 0.3476, Batch Acc: 0.8750
# [Batch 190/251] Loss: 0.5407, Batch Acc: 0.8750
# [Batch 200/251] Loss: 0.3026, Batch Acc: 0.8125
# [Batch 210/251] Loss: 0.5235, Batch Acc: 0.8750
# [Batch 220/251] Loss: 0.2049, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.4286, Batch Acc: 0.8750
# [Batch 240/251] Loss: 0.3967, Batch Acc: 0.8125
# [Batch 250/251] Loss: 0.2534, Batch Acc: 0.9375
# Epoch 8 Summary - Loss: 65.5314, Train Accuracy: 0.9144
# Validation Accuracy: 0.8971
#
# Epoch 9/10
# ------------------------------
# [Batch 10/251] Loss: 0.3699, Batch Acc: 0.9375
# [Batch 20/251] Loss: 0.0871, Batch Acc: 0.9375
# [Batch 30/251] Loss: 0.3953, Batch Acc: 0.8125
# [Batch 40/251] Loss: 0.1011, Batch Acc: 1.0000
# [Batch 50/251] Loss: 0.2513, Batch Acc: 0.8750
# [Batch 60/251] Loss: 0.3110, Batch Acc: 0.8750
# [Batch 70/251] Loss: 0.1990, Batch Acc: 0.9375
# [Batch 80/251] Loss: 0.2838, Batch Acc: 0.8125
# [Batch 90/251] Loss: 0.5972, Batch Acc: 0.8125
# [Batch 100/251] Loss: 0.6982, Batch Acc: 0.8750
# [Batch 110/251] Loss: 0.0484, Batch Acc: 1.0000
# [Batch 120/251] Loss: 0.1585, Batch Acc: 0.9375
# [Batch 130/251] Loss: 0.0637, Batch Acc: 1.0000
# [Batch 140/251] Loss: 0.3967, Batch Acc: 0.9375
# [Batch 150/251] Loss: 0.0358, Batch Acc: 1.0000
# [Batch 160/251] Loss: 0.0432, Batch Acc: 1.0000
# [Batch 170/251] Loss: 0.3678, Batch Acc: 0.8750
# [Batch 180/251] Loss: 0.4334, Batch Acc: 0.8750
# [Batch 190/251] Loss: 0.6246, Batch Acc: 0.8125
# [Batch 200/251] Loss: 0.2426, Batch Acc: 0.8125
# [Batch 210/251] Loss: 0.1486, Batch Acc: 0.9375
# [Batch 220/251] Loss: 0.2204, Batch Acc: 0.8750
# [Batch 230/251] Loss: 0.1098, Batch Acc: 0.9375
# [Batch 240/251] Loss: 0.2268, Batch Acc: 0.8750
# [Batch 250/251] Loss: 0.1831, Batch Acc: 0.9375
# Epoch 9 Summary - Loss: 57.2584, Train Accuracy: 0.9202
# Validation Accuracy: 0.8853
#
# Epoch 10/10
# ------------------------------
# [Batch 10/251] Loss: 0.0435, Batch Acc: 1.0000
# [Batch 20/251] Loss: 0.0023, Batch Acc: 1.0000
# [Batch 30/251] Loss: 0.0064, Batch Acc: 1.0000
# [Batch 40/251] Loss: 0.8298, Batch Acc: 0.8125
# [Batch 50/251] Loss: 0.0057, Batch Acc: 1.0000
# [Batch 60/251] Loss: 0.0694, Batch Acc: 1.0000
# [Batch 70/251] Loss: 0.2864, Batch Acc: 0.8750
# [Batch 80/251] Loss: 0.0519, Batch Acc: 1.0000
# [Batch 90/251] Loss: 0.3791, Batch Acc: 0.8125
# [Batch 100/251] Loss: 0.0127, Batch Acc: 1.0000
# [Batch 110/251] Loss: 0.2906, Batch Acc: 0.8750
# [Batch 120/251] Loss: 0.1066, Batch Acc: 1.0000
# [Batch 130/251] Loss: 0.2869, Batch Acc: 0.9375
# [Batch 140/251] Loss: 0.3792, Batch Acc: 0.9375
# [Batch 150/251] Loss: 0.4626, Batch Acc: 0.8125
# [Batch 160/251] Loss: 0.2059, Batch Acc: 0.8750
# [Batch 170/251] Loss: 0.0712, Batch Acc: 0.9375
# [Batch 180/251] Loss: 0.1749, Batch Acc: 0.9375
# [Batch 190/251] Loss: 0.0802, Batch Acc: 0.9375
# [Batch 200/251] Loss: 0.5753, Batch Acc: 0.8750
# [Batch 210/251] Loss: 0.2246, Batch Acc: 0.9375
# [Batch 220/251] Loss: 0.8687, Batch Acc: 0.8125
# [Batch 230/251] Loss: 0.0900, Batch Acc: 0.9375
# [Batch 240/251] Loss: 0.5818, Batch Acc: 0.6875
# [Batch 250/251] Loss: 0.0178, Batch Acc: 1.0000
# Epoch 10 Summary - Loss: 61.5926, Train Accuracy: 0.9182
# Validation Accuracy: 0.8813
